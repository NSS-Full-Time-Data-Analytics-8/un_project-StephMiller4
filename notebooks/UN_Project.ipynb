# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2020  1970.560169              NaN
# 1     Afghanistan  2019  2065.036235              NaN
# 2     Afghanistan  2018  2033.804389              NaN
# 3     Afghanistan  2017  2058.400221              NaN
# 4     Afghanistan  2016  2057.067978              NaN
# 5     Afghanistan  2015  2068.265904              NaN

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows = 4495 )
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
gdp_df.shape
internet_df.shape
# Out:
# (4495, 4)

# %% [markdown]
# ### 98.) SHAPE
# gdp_df's shape is 7176 x 4,
# internet_df's shape is 4676 x 4

# %%
result1 = gdp_df.dtypes
print(result1)
result2 = gdp_df.dtypes
print(result2)
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# ### 6.) DATA TYPE
# GDP
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object
#
# Internet
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# ### 99.)
# Take a look at the last 10 rows of each DataFrame in turn.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7166        Zimbabwe  1999  2872.714795              NaN
# 7167        Zimbabwe  1998  2915.052992              NaN
# 7168        Zimbabwe  1997  2856.118188              NaN
# 7169        Zimbabwe  1996  2808.558556              NaN
# 7170        Zimbabwe  1995  2573.993785              NaN
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# ### 7.)
# Drop the `value footnotes` column from both DataFrames. Check that this worked as expected.

# %%
gdp_df2= gdp_df.drop(columns = ['Value Footnotes'])
#gdp_df2 is the same as gdp_df but without the value footnotes column
print (gdp_df2)
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
internet_df2 = internet_df.drop(columns = ['Value Footnotes'])
#gdp_df2 is the same as gdp_df but without the value footnotes column
print (internet_df2)
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# ### 8.)
# Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df2.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df2.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2020     1970.560169
# 1  Afghanistan  2019     2065.036235
# 2  Afghanistan  2018     2033.804389
# 3  Afghanistan  2017     2058.400221
# 4  Afghanistan  2016     2057.067978

# %% [markdown]
# ### 9.)
# Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df2.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df2.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %% [markdown]
# ### 10.)
# Merge the two DataFrames to one. Merge **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`.

# %%
gdp_and_internet_use = pd.merge(gdp_df2, internet_df2, on=['Country', 'Year'] , how='outer')
gdp_and_internet_use
##If there are multiple columns that match up, it might make sense to merge on both to make sure all rows are included.
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2020     1970.560169                 NaN
# 1     Afghanistan  2019     2065.036235                 NaN
# 2     Afghanistan  2018     2033.804389                 NaN
# 3     Afghanistan  2017     2058.400221                 NaN
# 4     Afghanistan  2016     2057.067978                 NaN
# ...           ...   ...             ...                 ...
# 8251        Yemen  1999             NaN            0.056629
# 8252        Yemen  1998             NaN            0.023323
# 8253        Yemen  1997             NaN            0.015025
# 8254        Yemen  1996             NaN            0.000621
# 8255        Yemen  1990             NaN            0.000000
#
# [8256 rows x 4 columns]

# %% [markdown]
# ### 11 &12.)
# Look at the first five rows of your new DataFrame to confirm it merged correctly.
# Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2020     1970.560169                 NaN
# 1  Afghanistan  2019     2065.036235                 NaN
# 2  Afghanistan  2018     2033.804389                 NaN
# 3  Afghanistan  2017     2058.400221                 NaN
# 4  Afghanistan  2016     2057.067978                 NaN

# %%
gdp_and_internet_use.tail()
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 8251   Yemen  1999             NaN            0.056629
# 8252   Yemen  1998             NaN            0.023323
# 8253   Yemen  1997             NaN            0.015025
# 8254   Yemen  1996             NaN            0.000621
# 8255   Yemen  1990             NaN            0.000000

# %% [markdown]
# ### 13.)
# Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
year_subset = gdp_and_internet_use.loc[(gdp_and_internet_use.Year == 2004) | (gdp_and_internet_use.Year == 2009) | (gdp_and_internet_use.Year == 2014) ] 
year_subset
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6                     Afghanistan  2014     2102.384604            6.390000
# 11                    Afghanistan  2009     1758.904477            3.550000
# 16                    Afghanistan  2004     1200.278013            0.105809
# 25    Africa Eastern and Southern  2014     3677.319414                 NaN
# 30    Africa Eastern and Southern  2009     3461.681409                 NaN
# ...                           ...   ...             ...                 ...
# 8219        Virgin Islands (U.S.)  2009             NaN           27.396510
# 8224        Virgin Islands (U.S.)  2004             NaN           27.377009
# 8236                        Yemen  2014             NaN           22.550000
# 8241                        Yemen  2009             NaN            9.960000
# 8246                        Yemen  2004             NaN            0.881223
#
# [841 rows x 4 columns]

# %% [markdown]
# ### 14.)
# Create three new DataFrames, one for 2004, one for 2009, and one for 2014.
# Give them meaningful names that aren't too long.

# %%
gdp_and_net_use2004 = gdp_and_internet_use.loc[(gdp_and_internet_use.Year == 2004)]
gdp_and_net_use2004
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 16                    Afghanistan  2004     1200.278013            0.105809
# 35    Africa Eastern and Southern  2004     3093.224738                 NaN
# 66     Africa Western and Central  2004     3165.091102                 NaN
# 97                        Albania  2004     7580.138864            2.420388
# 128                       Algeria  2004    10058.426227            4.634475
# ...                           ...   ...             ...                 ...
# 8157                       Turkey  2004             NaN           14.580000
# 8180                    Venezuela  2004             NaN            8.404470
# 8204                     Viet Nam  2004             NaN            7.642409
# 8224        Virgin Islands (U.S.)  2004             NaN           27.377009
# 8246                        Yemen  2004             NaN            0.881223
#
# [279 rows x 4 columns]

# %%
gdp_and_net_use2009 = gdp_and_internet_use.loc[(gdp_and_internet_use.Year == 2009)]
gdp_and_net_use2009
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 11                    Afghanistan  2009     1758.904477             3.55000
# 30    Africa Eastern and Southern  2009     3461.681409                 NaN
# 61     Africa Western and Central  2009     3652.114030                 NaN
# 92                        Albania  2009    10313.916338            41.20000
# 123                       Algeria  2009    10782.347384            11.23000
# ...                           ...   ...             ...                 ...
# 8152                       Turkey  2009             NaN            36.40000
# 8175                    Venezuela  2009             NaN            32.70000
# 8199                     Viet Nam  2009             NaN            26.55000
# 8219        Virgin Islands (U.S.)  2009             NaN            27.39651
# 8241                        Yemen  2009             NaN             9.96000
#
# [281 rows x 4 columns]

# %%
gdp_and_net_use2014 = gdp_and_internet_use.loc[(gdp_and_internet_use.Year == 2014)]
gdp_and_net_use2014
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6                     Afghanistan  2014     2102.384604                6.39
# 25    Africa Eastern and Southern  2014     3677.319414                 NaN
# 56     Africa Western and Central  2014     4215.646000                 NaN
# 87                        Albania  2014    11586.833878               60.10
# 118                       Algeria  2014    11512.690472               18.09
# ...                           ...   ...             ...                 ...
# 8147                       Turkey  2014             NaN               51.04
# 8170                    Venezuela  2014             NaN               57.00
# 8194                     Viet Nam  2014             NaN               48.31
# 8214        Virgin Islands (U.S.)  2014             NaN               50.07
# 8236                        Yemen  2014             NaN               22.55
#
# [281 rows x 4 columns]

# %% [markdown]
# ### 15.)
# Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
maxnet2014_df = gdp_and_net_use2014.loc[(gdp_and_internet_use.Internet_Users_Pct == gdp_and_net_use2014.Internet_Users_Pct.max())]
maxnet2014_df
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2803  Iceland  2014    50450.741612               98.16

# %% [markdown]
# ### 16.)
# Which country had the lowest percentage of internet users in 2014? What was the percentage?

# %%
minnet2014_df = gdp_and_net_use2014.loc[(gdp_and_net_use2014.Internet_Users_Pct == gdp_and_internet_use.Internet_Users_Pct.min())]
minnet2014_df
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7394  Dem. People's Rep. of Korea  2014             NaN                 0.0

# %% [markdown]
# ### 17.)
# Repeat for 2004 and 2009.

# %%
maxnet2004_df = gdp_and_net_use2004.loc[(gdp_and_internet_use.Internet_Users_Pct == gdp_and_net_use2004.Internet_Users_Pct.max())]
maxnet2004_df
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6298  Sweden  2004    44354.391062               83.89

# %%
minnet2004_df = gdp_and_net_use2004.loc[(gdp_and_net_use2004.Internet_Users_Pct == gdp_and_internet_use.Internet_Users_Pct.min())]
minnet2004_df
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7403  Dem. People's Rep. of Korea  2004             NaN                 0.0

# %%
maxnet2009_df = gdp_and_net_use2009.loc[(gdp_and_internet_use.Internet_Users_Pct == gdp_and_net_use2009.Internet_Users_Pct.max())]
maxnet2009_df
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2808  Iceland  2009    48770.950337                93.0

# %%
minnet2009_df = gdp_and_net_use2009.loc[(gdp_and_net_use2009.Internet_Users_Pct == gdp_and_internet_use.Internet_Users_Pct.min())]
minnet2009_df
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7398  Dem. People's Rep. of Korea  2009             NaN                 0.0

# %% [markdown]
# ### 18.)
# Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
max_gdp2014_df = gdp_and_net_use2014.loc[(gdp_and_net_use2014.GDP_Per_Capita == gdp_and_net_use2014.GDP_Per_Capita.max())]
max_gdp2014_df
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3919  Macao SAR, China  2014   155201.740571                 NaN

# %% [markdown]
# ### 20.)
# Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
min_gdp2014_df = gdp_and_net_use2014.loc[(gdp_and_net_use2014.GDP_Per_Capita == gdp_and_net_use2014.GDP_Per_Capita.min())]
min_gdp2014_df
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1142  Central African Republic  2014      822.611195                 NaN

# %% [markdown]
# ### 21.)
# Create some scatterplots:
#     a.  2004 Percent Using the Internet vs GDP Per Capita
#     b.	2009 Percent Using the Internet vs GDP Per Capita
#     c.	2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', data = gdp_and_net_use2004)
plt.xlabel('Internet Users Percent')
plt.ylabel('GDP Per Capita')
plt.title ('2004 Percent Using the Internet vs GDP Per Capita');

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', data = gdp_and_net_use2009)
plt.xlabel('Internet Users Percent')
plt.ylabel('GDP Per Capita')
plt.title ('2009 Percent Using the Internet vs GDP Per Capita');

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', data = gdp_and_net_use2014)
plt.xlabel('Internet Users Percent')
plt.ylabel('GDP Per Capita')
plt.title ('2014 Percent Using the Internet vs GDP Per Capita');

# %% [markdown]
# ### 22.)
# #### Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# As time goes by the internet usage has become more accessible to countries with a lower GDP per capita.

# %% [markdown]
# ### 23.)
# #### Look at the distribution of gdp per capita values for 2014. Is it unimodal?
# Yes, see chart below with trendline, only shows 1 peak

# %%
sns.lmplot(x='Internet_Users_Pct', y='GDP_Per_Capita', data=gdp_and_net_use2014, ci=None)

# %%
sns.histplot(gdp_and_net_use2014, x='GDP_Per_Capita', bins =15);

# %% [markdown]
# ### 25.)
# What are the top 5 countries in terms of internet use in 2014?

# %%
top_5_2014_df = gdp_and_net_use2014.nlargest(5,'Internet_Users_Pct')
top_5_2014_df
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2803  Iceland  2014    50450.741612               98.16
# 645   Bermuda  2014    77361.104881               96.80
# 4880   Norway  2014    62390.130313               96.30
# 1561  Denmark  2014    52048.335493               95.99
# 7179  Andorra  2014             NaN               95.90

# %% [markdown]
# ### 26.)
# Create a DataFrame called top_5_internet **from the combined DataFrame that has all three years _for the 5 countries that had the greatest 2014 internet usage_**. You should have 15 rows. Check that this is true.

# %%
data = ['Iceland','Bermuda','Norway','Denmark', 'Andorra']
top_5_manual_df = pd.DataFrame(data, columns=['Country'])
top_5_manual_df
# Out:
#    Country
# 0  Iceland
# 1  Bermuda
# 2   Norway
# 3  Denmark
# 4  Andorra

# %%
top_5_internet1 = pd.merge(top_5_manual_df, year_subset, on=['Country'] , how='inner' ) 
top_5_internet1
##This is the hard way to do it, maybe not practical but correct answer. I could have also used a
## mask (.loc) to mask just the countries top_5_2014_df.
# Out:
#     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Iceland  2014    50450.741612           98.160000
# 1   Iceland  2009    48770.950337           93.000000
# 2   Iceland  2004    46051.743888           83.880000
# 3   Bermuda  2014    77361.104881           96.800000
# 4   Bermuda  2009    89961.982744           83.250000
# 5   Bermuda  2004    90195.811565           60.990867
# 6    Norway  2014    62390.130313           96.300000
# 7    Norway  2009    61689.558543           92.080000
# 8    Norway  2004    60699.566582           77.690000
# 9   Denmark  2014    52048.335493           95.990000
# 10  Denmark  2009    50114.050052           86.840000
# 11  Denmark  2004    50446.541605           80.930000
# 12  Andorra  2014             NaN           95.900000
# 13  Andorra  2009             NaN           78.530000
# 14  Andorra  2004             NaN           26.837954

# %%
top_5_internet2 = pd.merge(top_5_2014_df, year_subset, on=['Country']
                          , how='inner' ) 
top_5_internet2
##Again, correct-ish answer, need to not have each column twice (with x and y)
# Out:
#     Country  Year_x  GDP_Per_Capita_x  Internet_Users_Pct_x  Year_y  \
# 0   Iceland    2014      50450.741612                 98.16    2014
# 1   Iceland    2014      50450.741612                 98.16    2009
# 2   Iceland    2014      50450.741612                 98.16    2004
# 3   Bermuda    2014      77361.104881                 96.80    2014
# 4   Bermuda    2014      77361.104881                 96.80    2009
# 5   Bermuda    2014      77361.104881                 96.80    2004
# 6    Norway    2014      62390.130313                 96.30    2014
# 7    Norway    2014      62390.130313                 96.30    2009
# 8    Norway    2014      62390.130313                 96.30    2004
# 9   Denmark    2014      52048.335493                 95.99    2014
# 10  Denmark    2014      52048.335493                 95.99    2009
# 11  Denmark    2014      52048.335493                 95.99    2004
# 12  Andorra    2014               NaN                 95.90    2014
# ...

# %% [markdown]
# ### 27.)
# Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?

# %%
top_5_internet_chart = sns.FacetGrid(top_5_internet1, col='Country')
top_5_internet_chart.map_dataframe(sns.barplot, x = 'Year', y= 'Internet_Users_Pct');

# %% [markdown]
# ### 28.)
# Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?
# #### Dem. People's Rep. of Korea (aka North Korea)

# %%
bottom_5_2014_df = gdp_and_net_use2014.nsmallest(5,'Internet_Users_Pct')
bottom_5_2014_df
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7394  Dem. People's Rep. of Korea  2014             NaN                0.00
# 7452                      Eritrea  2014             NaN                0.99
# 6536                  Timor-Leste  2014     3266.731666                1.14
# 920                       Burundi  2014      886.235296                1.38
# 5877                      Somalia  2014      917.876549                1.63

# %%
bottom_5_2014_country= bottom_5_2014_df[['Country']]
bottom_5_2014_country
## This is how I should have done #26 properly
# Out:
#                           Country
# 7394  Dem. People's Rep. of Korea
# 7452                      Eritrea
# 6536                  Timor-Leste
# 920                       Burundi
# 5877                      Somalia

# %%
bottom_5_internet1 = pd.merge(bottom_5_2014_country, year_subset, on=['Country'] , how='inner' ) 
bottom_5_internet1
# Out:
#                         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Dem. People's Rep. of Korea  2014             NaN            0.000000
# 1   Dem. People's Rep. of Korea  2009             NaN            0.000000
# 2   Dem. People's Rep. of Korea  2004             NaN            0.000000
# 3                       Eritrea  2014             NaN            0.990000
# 4                       Eritrea  2009             NaN            0.540000
# 5                   Timor-Leste  2014     3266.731666            1.140000
# 6                   Timor-Leste  2009     2729.281474            0.185252
# 7                   Timor-Leste  2004     2258.384170                 NaN
# 8                       Burundi  2014      886.235296            1.380000
# 9                       Burundi  2009      831.564843            0.900000
# 10                      Burundi  2004      817.461177            0.349060
# 11                      Somalia  2014      917.876549            1.630000
# ...

# %% [markdown]
# ### 29.)
# Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
top5_gdp_2014_df = gdp_and_net_use2014.nlargest(5,'GDP_Per_Capita')
top5_gdp_2014_df
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3919  Macao SAR, China  2014   155201.740571                 NaN
# 3888        Luxembourg  2014   113313.578898               94.67
# 5387             Qatar  2014    95578.261511               91.49
# 5726         Singapore  2014    87616.637527               82.00
# 645            Bermuda  2014    77361.104881               96.80

# %%
top5_gdp_2014_country = top5_gdp_2014_df [['Country']]
top5_gdp_2014_country
# Out:
#                Country
# 3919  Macao SAR, China
# 3888        Luxembourg
# 5387             Qatar
# 5726         Singapore
# 645            Bermuda

# %%
top_5_gdp = pd.merge(top5_gdp_2014_country, year_subset, on=['Country'] , how='inner' ) 
top_5_gdp
# Out:
#              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Macao SAR, China  2014   155201.740571                 NaN
# 1   Macao SAR, China  2009    96493.793065                 NaN
# 2   Macao SAR, China  2004    73322.928480                 NaN
# 3         Luxembourg  2014   113313.578898           94.670000
# 4         Luxembourg  2009   112230.081410           87.310000
# 5         Luxembourg  2004   107634.837198           65.880000
# 6              Qatar  2014    95578.261511           91.490000
# 7              Qatar  2009    89954.846115           53.100000
# 8              Qatar  2004    93748.550125           20.701648
# 9          Singapore  2014    87616.637527           82.000000
# 10         Singapore  2009    69430.484671           69.000000
# 11         Singapore  2004    63862.123439           62.000000
# 12           Bermuda  2014    77361.104881           96.800000
# 13           Bermuda  2009    89961.982744           83.250000
# ...

# %%
top_5_gdp_chart = sns.FacetGrid(top_5_gdp, col='Country')
top_5_gdp_chart.map_dataframe(sns.barplot, x = 'Year', y= 'GDP_Per_Capita');

# %% [markdown]
# ### 96.)
# Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
bottom5_gdp_2014_df = gdp_and_net_use2014.nsmallest(5,'GDP_Per_Capita')
bottom5_gdp_2014_df
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1142  Central African Republic  2014      822.611195                 NaN
# 920                    Burundi  2014      886.235296                1.38
# 5877                   Somalia  2014      917.876549                1.63
# 1530           Dem. Rep. Congo  2014     1029.790813                 NaN
# 4756                     Niger  2014     1126.805440                1.95

# %%
bottom5_gdp_2014_Country = bottom5_gdp_2014_df [['Country']]
bottom5_gdp_2014_Country
# Out:
#                        Country
# 1142  Central African Republic
# 920                    Burundi
# 5877                   Somalia
# 1530           Dem. Rep. Congo
# 4756                     Niger

# %%
bottom_5_gdp = pd.merge(bottom5_gdp_2014_Country, year_subset, on=['Country'] , how='inner' ) 
bottom_5_gdp
# Out:
#                      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Central African Republic  2014      822.611195                 NaN
# 1   Central African Republic  2009     1161.190011                 NaN
# 2   Central African Republic  2004     1037.844670                 NaN
# 3                    Burundi  2014      886.235296            1.380000
# 4                    Burundi  2009      831.564843            0.900000
# 5                    Burundi  2004      817.461177            0.349060
# 6                    Somalia  2014      917.876549            1.630000
# 7                    Somalia  2009             NaN            1.160611
# 8                    Somalia  2004             NaN            1.053455
# 9            Dem. Rep. Congo  2014     1029.790813                 NaN
# 10           Dem. Rep. Congo  2009      835.611723                 NaN
# 11           Dem. Rep. Congo  2004      757.686099                 NaN
# ...

# %%
bottom_5_gdp_chart = sns.FacetGrid(bottom_5_gdp, col='Country')
bottom_5_gdp_chart.map_dataframe(sns.barplot, x = 'Year', y= 'GDP_Per_Capita');

# %% [markdown]
# ### 30.)
# #### Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?
#
# I was suprised to learn that Bermuda has such high internet usage.
# Bermuda has:
#
# 3 undersea connections (NJ, MIA, NY) and doubled down undersea capacity with a new line up and on-island caching to increase streaming throughputs
#
# 5 physical exchange sites across the island providing FTTx availability to 96% of the population, covering a majority of dwellings across Bermuda
#
# Across island LTE coverage; coverage has an uptime of 99.8% (data speeds vary depending on device)
#
# Proven network – A range of superyachts in Bermuda are currently using Mifi devices and LTE to stream to their guests on the boat; it's fast to deploy and fixed price unlimited LTE internet
#
# Bermuda Tourism Authority. (n.d.). Bermuda Boasts Reliable Wi Fi Across The Island. Go to Bermuda. Retrieved October 27, 2022,      from https://www.gotobermuda.com/inspiration/article/bermuda-boasts-reliable-wi-fi-across-island
